# %%
csv_ccharppi = '../CCharPPI/results_1K8R.csv' # subset
csv_boltz = '../22dataset_Boltz2_Features/resultados_complejos_mutados.csv'

# %%
import pandas as pd

# Cargar los CSV
df1 = pd.read_csv(csv_ccharppi)
df2 = pd.read_csv(csv_boltz)

# %%
df1.head(2)
# Out:
#                   pdb1 chains_pdb1                 pdb2 chains_pdb2  CP_BFKV  \
# 0  1K8R_B.Q15A_model_2           A  1K8R_B.Q15A_model_2           B  -2.3506
# 1  1K8R_A.D38N_model_2           A  1K8R_A.D38N_model_2           B  -2.8374
#
#    CP_BL  CP_BT  CP_GKS  CP_HLPL  CP_MJPL  ...  AP_PISA  FIREDOCK  \
# 0 -6.434  -4.76    -9.0    -18.4   -106.4  ...  -0.3144       0.0
# 1 -4.168  -4.38    -8.2    -20.8   -103.4  ...  -0.3043       0.0
#
#    FIREDOCK_AB  FIREDOCK_EI    CP_PIE  CP_DDG_U  CP_DDG_W   AP_DDG_U  \
# 0          0.0          0.0  1.040522 -6.960470 -8.806148 -12.465564
# 1          0.0          0.0  1.031829 -5.847363 -8.237123 -10.485541
#
#     AP_DDG_W      DDG_V
# 0 -14.348640 -12.663401
# 1 -13.757906 -13.194021
#
# [2 rows x 112 columns]

# %%
df2.head(2)
# Out:
#                            filename  confidence_score       ptm      iptm  \
# 0  confidence_4RS1_A.K181A_model_13          0.931547  0.888373  0.935870
# 1  confidence_4RS1_A.K181A_model_12          0.931852  0.882690  0.932112
#
#    ligand_iptm  protein_iptm  complex_plddt  complex_iplddt  complex_pde  \
# 0          0.0      0.935870       0.930466        0.936301     0.376106
# 1          0.0      0.932112       0.931787        0.937234     0.391876
#
#    complex_ipde  chains_ptm_0  chains_ptm_1  pair_chains_iptm_0_0  \
# 0      0.764951      0.865155      0.980190              0.865155
# 1      0.814329      0.858234      0.978904              0.858234
#
#    pair_chains_iptm_0_1  pair_chains_iptm_1_0  pair_chains_iptm_1_1
# 0              0.855278              0.935870              0.980190
# 1              0.848020              0.932112              0.978904

# %%
# Cambiar nombre de columna en los dos a ID




# Eliminar el inicio de 'confidence' en 4RS1

# %%
# Unir por la columna 'ID'
df_merged = pd.merge(df1, df2, on='ID')

# Guardar resultado
df_merged.to_csv('archivo_unido.csv', index=False)

print(df_merged)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_29522/4205391371.py in ?()
#       1 # Unir por la columna 'ID'
# ----> 2 df_merged = pd.merge(df1, df2, on='ID')
#       3
#       4 # Guardar resultado
#       5 df_merged.to_csv('archivo_unido.csv', index=False)
#
# /usr/lib/python3/dist-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# /usr/lib/python3/dist-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
# ...
